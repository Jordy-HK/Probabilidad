# %% [markdown]
# <a href="https://colab.research.google.com/github/Jordy-HK/Probabilidad/blob/main/Unidad3/Ejercicio2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Probabilidad y estadistica
# ## Unidad 3
# ### Facilitador: Jose Gabriel Rodriguez Rivas
# ### Alumno: Jordy German Montor de Santiago
# ### **Ejercicio 2**

# %%
#Distribucion de Probabilidad
import matplotlib.pyplot as plt
# Valores de la variable aleatoria
x = [0, 10, 20, 50]
p = [0.50, 0.30, 0.15, 0.05]
# Verificar suma = 1
print("Suma de probabilidades:", sum(p))
# Graficar distribución
plt.stem(x, p)
plt.title("Distribución de Probabilidad")
plt.xlabel("Monto (Pesos)")
plt.ylabel("Probabilidad")
plt.grid(True)
plt.show()
# Out:
# Suma de probabilidades: 1.0

# %%
# Valor Esperado
x = [0, 10, 20, 50]
p = [0.50, 0.30, 0.15, 0.05]
valor_esperado = 0
for i in range(len(x)):
  xi = x[i]
  pi = p[i]
  producto = xi * pi
  valor_esperado += producto
print(f"x = {xi}, p = {pi}, x*p = {producto:.2f}")
print(f"\nGanancia Promedio Esperado: {valor_esperado:.2f}")
# Out:
# x = 50, p = 0.05, x*p = 2.50
#
# Ganancia Promedio Esperado: 8.50

# %%
# Varianza y Desviacion Estandar
import math
x = [0, 10, 20, 50]
p = [0.50, 0.30, 0.15, 0.05]
esperanza = 0
for i in range(len(x)):
  esperanza += x[i] * p[i]
esperanza_cuadrado = 0
for i in range(len(x)):
  esperanza_cuadrado += (x[i]**2)*p[i]
varianza = esperanza_cuadrado - esperanza ** 2
desviacion = math.sqrt(varianza)
print(f"E(X)={esperanza:.2f}")
print(f"E(X^2)={esperanza_cuadrado:.2f}")
print(f"Varianza = {varianza:.2f}")
print(f"Desviacion Estandar = {desviacion:.2f}")
# Out:
# E(X)=8.50
# E(X^2)=215.00
# Varianza = 142.75
# Desviacion Estandar = 11.95

# %%
# Funcion de Distribucion Acumulada
import math
import numpy as np
import matplotlib.pyplot as plt
x = [0, 10, 20, 50]
p = [0.50, 0.30, 0.15, 0.05]
F=np.cumsum(p)
for xi, fi in zip(x, F):
    print(f"F={xi} = {fi:.2f}")
plt.step(x, F, where='post')
plt.title("Funcion de Distribucion Acumulada (FDA)")
plt.xlabel("Monto (Pesos)")
plt.ylabel("Probabilidad Acumulada")
plt.grid(True)
plt.ylim(0, 1.05)
plt.show()
# Out:
# F=0 = 0.50
# F=10 = 0.80
# F=20 = 0.95
# F=50 = 1.00
