# %% [markdown]
# <a href="https://colab.research.google.com/github/Jordy-HK/Probabilidad/blob/main/Unidad3/Ejercicio3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Probabilidad y estadistica
# ## Unidad 3
# ### Facilitador: Jose Gabriel Rodriguez Rivas
# ### Alumno: Jordy German Montor de Santiago
# ### **Ejercicio 3**

# %%
#Distribucion de Probabilidad
import matplotlib.pyplot as plt
# Valores de la variable aleatoria
x = [0, 1, 2, 3, 4, 5]
p = [0.05, 0.10, 0.25, 0.30, 0.20, 0.10]
# Verificar suma = 1
print("Suma de probabilidades:", sum(p))
# Graficar distribución
plt.stem(x, p)
plt.title("Distribución de Probabilidad")
plt.xlabel("Unidades Vendidas")
plt.ylabel("Probabilidad")
plt.grid(True)
plt.show()
# Out:
# Suma de probabilidades: 1.0

# %%
# Valor Esperado
x = [0, 1, 2, 3, 4, 5]
p = [0.05, 0.10, 0.25, 0.30, 0.20, 0.10]
valor_esperado = 0
for i in range(len(x)):
  xi = x[i]
  pi = p[i]
  producto = xi * pi
  valor_esperado += producto
print(f"x = {xi}, p = {pi}, x*p = {producto:.2f}")
print(f"\nNumero Promedio de Ventas: {valor_esperado:.2f}")
# Out:
# x = 5, p = 0.1, x*p = 0.50
#
# Numero Promedio de Ventas: 2.80

# %%
# Varianza y Desviacion Estandar
import math
x = [0, 1, 2, 3, 4, 5]
p = [0.05, 0.10, 0.25, 0.30, 0.20, 0.10]
esperanza = 0
for i in range(len(x)):
  esperanza += x[i] * p[i]
esperanza_cuadrado = 0
for i in range(len(x)):
  esperanza_cuadrado += (x[i]**2)*p[i]
varianza = esperanza_cuadrado - esperanza ** 2
desviacion = math.sqrt(varianza)
print(f"E(X)={esperanza:.2f}")
print(f"E(X^2)={esperanza_cuadrado:.2f}")
print(f"Varianza = {varianza:.2f}")
print(f"Desviacion Estandar = {desviacion:.2f}")
# Out:
# E(X)=2.80
# E(X^2)=9.50
# Varianza = 1.66
# Desviacion Estandar = 1.29

# %%
# Funcion de Distribucion Acumulada
import math
import numpy as np
import matplotlib.pyplot as plt
x = [0, 1, 2, 3, 4, 5]
p = [0.05, 0.10, 0.25, 0.30, 0.20, 0.10]
F=np.cumsum(p)
for xi, fi in zip(x, F):
    print(f"F={xi} = {fi:.2f}")
plt.step(x, F, where='post')
plt.title("Funcion de Distribucion Acumulada (FDA)")
plt.xlabel("Unidades Vendidas")
plt.ylabel("Probabilidad Acumulada")
plt.grid(True)
plt.ylim(0, 1.05)
plt.show()
# Out:
# F=0 = 0.05
# F=1 = 0.15
# F=2 = 0.40
# F=3 = 0.70
# F=4 = 0.90
# F=5 = 1.00
