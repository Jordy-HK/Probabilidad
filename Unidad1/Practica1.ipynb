# %% [markdown]
# <a href="https://colab.research.google.com/github/Jordy-HK/Probabilidad/blob/main/Unidad1/Practica1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Probabilidad y estadistica
# ## Unidad 1
# ### Facilitador: Jose Gabriel Rodriguez Rivas
# ### Alumno: Jordy German Montor de Santiago
# ### **Programa 1: Estadistica basica e Histogramas**

# %%
from statistics import *
grupoa = [20, 87, 98, 99, 100, 100, 50, 68, 70, 80, 85, 96,]
print(grupoa)
type(grupoa)
promedio = sum(grupoa)/len(grupoa)
print(promedio)

promedio2 = mean(grupoa)
print(promedio2)

mediana = median(grupoa)
print(mediana)
moda = mode(grupoa)
print(moda)
moda2 = multimode(grupoa)
print(moda2)
# Out:
# [20, 87, 98, 99, 100, 100, 50, 68, 70, 80, 85, 96]
# 79.41666666666667
# 79.41666666666667
# 86.0
# 100
# [100]

# %%
tiempos100mts = [15.10, 12.30, 14.11, 11.02, 20.14, 10.01, 9.99, 9.89, 16.25, 11.98]
print(tiempos100mts)
print("El tiempo promedio de los corredores es: ", mean(tiempos100mts))
print("El tiempo mediano de los corredores es: ", median(tiempos100mts))
print("El tiempo de la moda de los corredores es: ", mode(tiempos100mts))
# Out:
# [15.1, 12.3, 14.11, 11.02, 20.14, 10.01, 9.99, 9.89, 16.25, 11.98]
# El tiempo promedio de los corredores es:  13.079
# El tiempo mediano de los corredores es:  12.14
# El tiempo de la moda de los corredores es:  15.1

# %%
import random
fabrica1 = []
for i in range(100):
  numero_aleatorio = round(random.uniform(50, 100), 2)
  fabrica1.append(numero_aleatorio)
print(fabrica1)

fabrica2 = []
for i in range(100):
  numero_aleatorio = round(random.uniform(50, 100), 2)
  fabrica2.append(numero_aleatorio)
print(fabrica2)
# Out:
# [82.01, 98.72, 87.04, 91.95, 99.42, 60.86, 78.3, 86.19, 60.25, 70.34, 82.29, 62.26, 82.92, 60.42, 70.3, 76.36, 65.72, 64.89, 88.63, 68.54, 89.8, 84.9, 94.74, 54.47, 51.14, 64.33, 55.25, 87.25, 99.47, 87.22, 62.16, 54.23, 52.35, 81.64, 74.16, 70.39, 85.39, 94.49, 95.48, 77.25, 82.92, 83.46, 96.44, 94.16, 55.04, 71.08, 50.7, 72.4, 61.55, 90.97, 91.95, 53.75, 86.39, 69.04, 53.39, 75.71, 98.42, 68.84, 97.25, 89.16, 71.81, 73.2, 85.79, 84.89, 63.34, 76.8, 67.62, 85.08, 50.89, 73.49, 74.63, 55.05, 77.64, 89.42, 96.46, 96.9, 70.33, 80.08, 89.04, 81.56, 92.08, 69.06, 68.58, 97.13, 75.7, 92.77, 56.9, 56.27, 94.95, 92.99, 71.59, 78.69, 55.99, 79.91, 82.66, 70.88, 52.45, 73.27, 66.04, 72.84]
# [53.01, 50.96, 84.54, 82.51, 99.12, 61.62, 85.48, 69.74, 87.06, 72.73, 99.89, 99.87, 51.35, 81.5, 51.22, 86.37, 99.38, 66.74, 72.17, 76.71, 88.92, 87.62, 98.32, 61.51, 59.55, 73.62, 63.96, 50.45, 57.78, 89.28, 59.38, 84.68, 90.25, 88.19, 78.14, 75.24, 51.65, 99.91, 88.04, 63.91, 75.51, 66.94, 52.04, 51.41, 83.7, 74.5, 93.64, 98.61, 76.2, 73.05, 53.25, 51.43, 85.93, 83.62, 74.91, 96.94, 94.82, 55.01, 60.0, 51.02, 51.57, 55.26, 71.93, 66.16, 68.05, 57.31, 60.91, 73.14, 80.2, 52.97, 57.15, 65.85, 53.82, 83.72, 68.27, 65.73, 93.52, 53.64, 82.98, 57.81, 55.68, 80.13, 78.14, 72.2, 92.61, 97.19, 97.51, 67.86, 92.72, 96.21, 58.78, 63.53, 79.27, 60.29, 53.32, 55.52, 52.41, 55.34, 55.6, 72.83]

# %%
import matplotlib.pyplot as plt
plt.hist(fabrica1)
plt.title("Produccion diaria de la fabrica 1")
# Out:
# Text(0.5, 1.0, 'Produccion diaria de la fabrica 1')

# %%
import matplotlib.pyplot as plt
plt.hist(fabrica2)
plt.title("Produccion diarria de la fabrica 2")
# Out:
# Text(0.5, 1.0, 'Produccion diarria de la fabrica 2')

# %%
media1 = mean(fabrica1)
mediana1 = median(fabrica1)
moda1 = mode(fabrica1)
print("Valores de la fabrica 1")
print("La media es: ", media1)
print("La median es: ", mediana1)
print("La moda es: ", moda1)

media2 = mean(fabrica2)
mediana2 = median(fabrica2)
moda2 = mode(fabrica2)
print("Valores de la fabrica 2")
print("La media es: ", media2)
print("La median es: ", mediana2)
print("La moda es: ", moda2)
# Out:
# Valores de la fabrica 1
# La media es:  76.4091
# La median es:  76.58
# La moda es:  91.95
# Valores de la fabrica 2
# La media es:  72.5203
# La median es:  72.465
# La moda es:  78.14

# %%
fig,(ax1, ax2) = plt.subplots(nrows = 1, ncols = 2, figsize = (10,5))
ax1.hist(fabrica1)
ax2.hist(fabrica2)
plt.show()
