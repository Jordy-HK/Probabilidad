# %% [markdown]
# <a href="https://colab.research.google.com/github/Jordy-HK/Probabilidad/blob/main/Unidad1/Pratica2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Probabilidad y estadistica
# ## Unidad 1
# ### **Practica 2: Maximo, Minimo, Rango y unidad de Datos.**
# ### Facilitador: Jose Gabriel Rodriguez Rivas
# ### Alumno: Jordy German Montor de Santiago

# %%
import random
import matplotlib.pyplot as plt
from statistics import *

# %%
fabrica1 = []
for i in range (100):
  numero_aleatorio = round(random.uniform(50,100), 2)
  fabrica1.append(numero_aleatorio)
print(fabrica1)

print("==========================================")

fabrica2 = []
for i in range (100):
  numero_aleatorio = round(random.uniform(50,100), 2)
  fabrica2.append(numero_aleatorio)
print(fabrica2)
print("===========================================")

maximo1=max(fabrica1)
minimo1=min(fabrica1)
rango1=maximo1-minimo1
media1=mean(fabrica1)
mediana1=median(fabrica1)
moda1=mode(fabrica1)
desviacion_estandar_fabrica1 = stdev(fabrica1)
print("Estadistica descriptiva de la fabrica 1 \n", "media =", media1,
      "\n mediana= ", mediana1, "\n moda= ", moda1, "\n maximo= ", maximo1,
      "\n minimo= ", minimo1, "\n rango= ", rango1)
print("La desviacion estandar es: ", desviacion_estandar_fabrica1)

maximo2=max(fabrica2)
minimo2=min(fabrica2)
rango2=maximo2-minimo2
media2=mean(fabrica2)
mediana2=median(fabrica2)
moda2=mode(fabrica2)
desviacion_estandar_fabrica2 = stdev(fabrica2)
print("Estadistica descriptiva de la fabrica 2 \n", "media =", media2,
      "\n mediana= ", mediana2, "\n moda= ", moda2, "\n maximo= ", maximo2,
      "\n minimo= ", minimo2, "\n rango= ", rango2)
print("La desviacion estandar es:", desviacion_estandar_fabrica2)
# Out:
# [59.87, 79.25, 58.37, 89.46, 62.48, 95.45, 76.36, 98.07, 74.47, 99.78, 78.36, 72.52, 84.44, 70.99, 91.76, 51.57, 82.31, 88.24, 69.17, 53.61, 60.81, 84.61, 56.21, 50.5, 80.05, 90.54, 57.0, 57.46, 87.1, 75.78, 85.98, 98.43, 89.71, 77.26, 51.47, 78.06, 68.83, 59.58, 54.46, 91.23, 91.45, 64.58, 59.21, 62.04, 94.83, 63.32, 58.73, 99.87, 95.31, 85.25, 52.63, 79.79, 55.63, 57.19, 70.33, 70.47, 93.1, 55.69, 66.53, 99.87, 83.52, 64.58, 67.29, 94.41, 95.86, 76.2, 90.68, 86.7, 67.78, 69.88, 89.34, 51.24, 65.76, 89.94, 65.06, 99.62, 83.97, 86.47, 58.86, 85.44, 63.95, 80.43, 58.24, 91.19, 85.69, 73.82, 51.51, 93.18, 97.35, 98.88, 72.0, 91.24, 82.48, 51.16, 60.49, 99.59, 73.13, 88.27, 75.64, 68.93]
# ==========================================
# [72.27, 84.45, 50.06, 64.32, 98.46, 63.93, 64.97, 72.11, 95.07, 84.56, 57.92, 91.35, 96.14, 75.15, 95.94, 74.66, 84.59, 83.89, 86.21, 54.49, 72.14, 63.3, 59.51, 55.9, 91.08, 61.95, 54.09, 90.91, 54.65, 97.37, 98.98, 57.95, 91.08, 70.29, 51.08, 97.46, 93.21, 54.42, 51.11, 68.2, 84.71, 66.85, 89.97, 99.92, 64.0, 53.55, 89.77, 61.07, 55.54, 77.05, 61.31, 80.5, 89.9, 65.08, 99.11, 80.88, 69.37, 51.42, 62.95, 62.99, 69.74, 87.51, 74.8, 92.11, 89.01, 83.28, 97.11, 77.55, 74.57, 99.53, 80.7, 53.98, 50.64, 57.95, 83.6, 87.85, 54.17, 80.31, 69.85, 62.05, 70.42, 54.16, 80.3, 80.61, 52.78, 59.46, 50.07, 74.89, 96.75, 99.53, 69.12, 83.25, 97.38, 99.83, 66.11, 98.33, 87.59, 82.66, 77.7, 56.27]
# ===========================================
# Estadistica descriptiva de la fabrica 1
#  media = 75.9719
#  mediana=  76.28
#  moda=  64.58
#  maximo=  99.87
#  minimo=  50.5
#  rango=  49.370000000000005
# La desviacion estandar es:  15.138939870213482
# Estadistica descriptiva de la fabrica 2
#  media = 75.1468
#  mediana=  74.845
#  moda=  91.08
#  maximo=  99.92
#  minimo=  50.06
#  rango=  49.86
# La desviacion estandar es: 15.737251173729499
