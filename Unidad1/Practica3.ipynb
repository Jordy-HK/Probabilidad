# %% [markdown]
# <a href="https://colab.research.google.com/github/Jordy-HK/Probabilidad/blob/main/Unidad1/Practica3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Probabilidad y estadistica
# ## Unidad 1
# ### **Practica 3: Tablas de Frecuencia.**
# ### Facilitador: Jose Gabriel Rodriguez Rivas
# ### Alumno: Jordy German Montor de Santiago

# %%
import random
edades=[]
for i in range(100):
  numero_aleatorio=random.randint(18,70)
  edades.append(numero_aleatorio)
print(edades)
print("================================")
import pandas as pd
df = pd.DataFrame(edades, columns=['Edad'])
df.head()
print("================================")
tabla_frecuencias=df['Edad'].value_counts().reset_index()
tabla_frecuencias.columns=['Edad', 'Frecuencia']
tabla_frecuencias=tabla_frecuencias.sort_values(by='Edad')
print('Tabla de distribucion de frecuencias:')
tabla_frecuencias

tabla_frecuencias['Frec. Relativa']=tabla_frecuencias['Frecuencia']/100
tabla_frecuencias

tabla_frecuencias['Frec. Porcentual']=tabla_frecuencias['Frecuencia']/100*100
tabla_frecuencias

tabla_frecuencias['Frec. Acumulada']=tabla_frecuencias['Frecuencia'].cumsum()
tabla_frecuencias
# Out:
# [29, 54, 65, 36, 55, 61, 27, 45, 62, 55, 60, 31, 18, 45, 47, 20, 60, 58, 67, 27, 21, 59, 24, 32, 26, 23, 63, 31, 34, 35, 36, 70, 21, 38, 54, 20, 55, 20, 33, 60, 45, 29, 56, 70, 37, 66, 35, 62, 46, 64, 53, 62, 55, 46, 27, 67, 19, 57, 64, 57, 70, 34, 37, 51, 20, 20, 64, 49, 18, 40, 65, 58, 35, 63, 66, 39, 30, 27, 60, 32, 24, 66, 33, 51, 55, 36, 35, 53, 57, 59, 21, 27, 30, 66, 48, 61, 60, 33, 27, 69]
# ================================
# ================================
# Tabla de distribucion de frecuencias:
#     Edad  Frecuencia  Frec. Relativa  Frec. Porcentual  Frec. Acumulada
# 26    18           2            0.02               2.0                2
# 37    19           1            0.01               1.0                3
# 3     20           5            0.05               5.0                8
# 13    21           3            0.03               3.0               11
# 32    23           1            0.01               1.0               12
# 20    24           2            0.02               2.0               14
# 33    26           1            0.01               1.0               15
# 0     27           6            0.06               6.0               21
# 15    29           2            0.02               2.0               23
# 27    30           2            0.02               2.0               25
# 14    31           2            0.02               2.0               27
# 21    32           2            0.02               2.0               29
# 11    33           3            0.03               3.0               32
# 19    34           2            0.02               2.0               34
# 4     35           4            0.04               4.0               38
# 9     36           3            0.03               3.0               41
# 30    37           2            0.02               2.0               43
# 35    38           1            0.01               1.0               44
# 40    39           1            0.01               1.0               45
# 39    40           1            0.01               1.0               46
# 8     45           3            0.03               3.0               49
# 28    46           2            0.02               2.0               51
# 34    47           1            0.01               1.0               52
# 41    48           1            0.01               1.0               53
# 38    49           1            0.01               1.0               54
# 29    51           2            0.02               2.0               56
# 31    53           2            0.02               2.0               58
# 17    54           2            0.02               2.0               60
# 1     55           5            0.05               5.0               65
# 36    56           1            0.01               1.0               66
# 10    57           3            0.03               3.0               69
# 25    58           2            0.02               2.0               71
# 23    59           2            0.02               2.0               73
# 2     60           5            0.05               5.0               78
# 16    61           2            0.02               2.0               80
# 6     62           3            0.03               3.0               83
# 22    63           2            0.02               2.0               85
# 12    64           3            0.03               3.0               88
# 18    65           2            0.02               2.0               90
# 5     66           4            0.04               4.0               94
# 24    67           2            0.02               2.0               96
# 42    69           1            0.01               1.0               97
# 7     70           3            0.03               3.0              100

# %%
import math
print(edades)
df = pd.DataFrame({'Edad': edades})
df
n = len(edades)
k = int(1 + math.log2(n))
print("Valor de n= ", n, "\nNumero de intervalos=", k)
tabla_frecuencias = pd.cut(df['Edad'], bins=k, include_lowest=True).value_counts().reset_index()
tabla_frecuencias.columns = ['Clase', 'Frec']
tabla_frecuencias
tabla_frecuencias = tabla_frecuencias.sort_values(by='Clase')
tabla_frecuencias

tabla_frecuencias['Frec. Rel'] = tabla_frecuencias['Frec']/n
tabla_frecuencias['Frec. Porc'] = tabla_frecuencias['Frec']/n*100
tabla_frecuencias['Frec. Ac'] = tabla_frecuencias['Frec'].cumsum()
tabla_frecuencias['Frec. Rel Ac'] = tabla_frecuencias['Frec'].cumsum()
tabla_frecuencias['Frec. Porc Ac'] = tabla_frecuencias['Frec'].cumsum()
print(tabla_frecuencias)
# Out:
# [29, 54, 65, 36, 55, 61, 27, 45, 62, 55, 60, 31, 18, 45, 47, 20, 60, 58, 67, 27, 21, 59, 24, 32, 26, 23, 63, 31, 34, 35, 36, 70, 21, 38, 54, 20, 55, 20, 33, 60, 45, 29, 56, 70, 37, 66, 35, 62, 46, 64, 53, 62, 55, 46, 27, 67, 19, 57, 64, 57, 70, 34, 37, 51, 20, 20, 64, 49, 18, 40, 65, 58, 35, 63, 66, 39, 30, 27, 60, 32, 24, 66, 33, 51, 55, 36, 35, 53, 57, 59, 21, 27, 30, 66, 48, 61, 60, 33, 27, 69]
# Valor de n=  100
# Numero de intervalos= 7
#               Clase  Frec  Frec. Rel  Frec. Porc  Frec. Ac  Frec. Rel Ac  \
# 4  (17.947, 25.429]    14       0.14        14.0        14            14
# 3  (25.429, 32.857]    15       0.15        15.0        29            29
# 2  (32.857, 40.286]    17       0.17        17.0        46            46
# 6  (40.286, 47.714]     6       0.06         6.0        52            52
# 5  (47.714, 55.143]    13       0.13        13.0        65            65
# 0  (55.143, 62.571]    18       0.18        18.0        83            83
# 1    (62.571, 70.0]    17       0.17        17.0       100           100
#
#    Frec. Porc Ac
# 4             14
# 3             29
# 2             46
# 6             52
# 5             65
# 0             83
# 1            100

# %%
import matplotlib.pyplot as plt
plt.hist(edades, alpha = 0.5)
plt.title("Histograma de edades basado en la funcion de matplotlib con valores estandar")
# Out:
# Text(0.5, 1.0, 'Histograma de edades basado en la funcion de matplotlib con valores estandar')

# %%
plt.hist(df['Edad'], bins=k, alpha = 0.5)
plt.title('Histograma de edades basado en la regla de Sturges')
plt.xlabel('Edades')
plt.ylabel('Frecuencias')
# Out:
# Text(0, 0.5, 'Frecuencias')
