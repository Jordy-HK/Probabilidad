# %% [markdown]
# <a href="https://colab.research.google.com/github/Jordy-HK/Probabilidad/blob/main/Unidad4/Programa1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Probabilidad y estadistica
# ## Unidad 3
# ### Facilitador: Jose Gabriel Rodriguez Rivas
# ### Alumno: Jordy German Montor de Santiago
# ### **Programa 1**

# %%
#Distribucion de Probabilidad
import matplotlib.pyplot as plt
# Valores de la variable aleatoria
x = [5, 6, 7, 8, 9, 10]
p = [0.05, 0.10, 0.20, 0.30, 0.25, 0.10]
# Verificar suma = 1
print("Suma de probabilidades:", sum(p))
# Graficar distribución
plt.stem(x, p)
plt.title("Distribución de Probabilidad")
plt.xlabel("Calificación")
plt.ylabel("Probabilidad")
plt.grid(True)
plt.show()
# Out:
# Suma de probabilidades: 1.0

# %%
# Valor Esperado
x = [5, 6, 7, 8, 9, 10]
p = [0.05, 0.10, 0.20, 0.30, 0.25, 0.10]
valor_esperado = 0
for i in range(len(x)):
  xi = x[i]
  pi = p[i]
  producto = xi * pi
  valor_esperado += producto
print(f"x = {xi}, p = {pi}, x*p = {producto:.2f}")
print(f"\nValor esperado (Esperanza): {valor_esperado:.2f}")
# Out:
# x = 10, p = 0.1, x*p = 1.00
#
# Valor esperado (Esperanza): 7.90

# %%
# Varianza y Desviacion Estandar
import math
x = [5, 6, 7, 8, 9, 10]
p = [0.05, 0.10, 0.20, 0.30, 0.25, 0.10]
esperanza = 0
for i in range(len(x)):
  esperanza += x[i] * p[i]
esperanza_cuadrado = 0
for i in range(len(x)):
  esperanza_cuadrado += (x[i]**2)*p[i]
varianza = esperanza_cuadrado - esperanza ** 2
desviacion = math.sqrt(varianza)
print(f"E(X)={esperanza:.2f}")
print(f"E(X^2)={esperanza_cuadrado:.2f}")
print(f"Varianza = {varianza:.2f}")
print(f"Desviacion Estandar = {desviacion:.2f}")
# Out:
# E(X)=7.90
# E(X^2)=64.10
# Varianza = 1.69
# Desviacion Estandar = 1.30

# %%
# Funcion de Distribucion Acumulada
import math
import numpy as np
import matplotlib.pyplot as plt
x = [5, 6, 7, 8, 9, 10]
p = [0.05, 0.10, 0.20, 0.30, 0.25, 0.10]
F=np.cumsum(p)
for xi, fi in zip(x, F):
    print(f"F={xi} = {fi:.2f}")
plt.step(x, F, where='post')
plt.title("Funcion de Distribucion Acumulada (FDA)")
plt.xlabel("Calificacion")
plt.ylabel("Probabilidad Acumulada")
plt.grid(True)
plt.ylim(0, 1.05)
plt.show()
# Out:
# F=5 = 0.05
# F=6 = 0.15
# F=7 = 0.35
# F=8 = 0.65
# F=9 = 0.90
# F=10 = 1.00

# %%
#Grafica de distribucion de probabilidad discreta
import matplotlib.pyplot as plt
import numpy as np
x = np.array([5, 6, 7, 8, 9, 10])
p = np.array([0.05, 0.10, 0.20, 0.30, 0.25, 0.10])
esperanza = np.sum(x*p)
esperanza_cuadrado = np.sum(x**2 *p)
varianza = esperanza_cuadrado - esperanza**2
desviacion = np.sqrt(varianza)
print(f"E(X)={esperanza:.2f}")
print(f"E(X^2)={esperanza_cuadrado:.2f}")
print(f"Varianza = {varianza:.2f}")
print(f"Desviacion Estandar = {desviacion:.2f}")
plt.stem(x, p, basefmt=" ", linefmt='b-', markerfmt='bo')
plt.title("Distribucion de probabilidad discreta\ncon Media y Desviacion Estandar")
plt.xlabel("P(X)")
plt.grid(True, linestyle='--', alpha=0.6)
plt.axvline(x=esperanza, color="red", linestyle="--", label=f"Media (E[X])={esperanza:.2f}")
plt.axvspan(esperanza-desviacion, esperanza + desviacion, color = 'red', alpha=0.2, label=f"+=1 Desviacion Estandar (o = {desviacion:.2f})")
plt.legend()
plt.ylim(0, max(p)+0.05)
plt.xticks(x)
plt.show()
# Out:
# E(X)=7.90
# E(X^2)=64.10
# Varianza = 1.69
# Desviacion Estandar = 1.30
