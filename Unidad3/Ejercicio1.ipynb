# %% [markdown]
# <a href="https://colab.research.google.com/github/Jordy-HK/Probabilidad/blob/main/Unidad3/Ejercicio1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Probabilidad y estadistica
# ## Unidad 3
# ### Facilitador: Jose Gabriel Rodriguez Rivas
# ### Alumno: Jordy German Montor de Santiago
# ### **Ejercicio 1**

# %%
#Distribucion de Probabilidad
import matplotlib.pyplot as plt
# Valores de la variable aleatoria
x = [0, 1, 2, 3, 4, 5]
p = [0.10, 0.25, 0.30, 0.20, 0.10, 0.05]
# Verificar suma = 1
print("Suma de probabilidades:", sum(p))
# Graficar distribución
plt.stem(x, p)
plt.title("Distribución de Probabilidad")
plt.xlabel("Numero de Celulas Anormales")
plt.ylabel("Probabilidad")
plt.grid(True)
plt.show()
# Out:
# Suma de probabilidades: 1.0

# %%
# Valor Esperado
x = [0, 1, 2, 3, 4, 5]
p = [0.10, 0.25, 0.30, 0.20, 0.10, 0.05]
valor_esperado = 0
for i in range(len(x)):
  xi = x[i]
  pi = p[i]
  producto = xi * pi
  valor_esperado += producto
print(f"x = {xi}, p = {pi}, x*p = {producto:.2f}")
print(f"\nValor esperado (Esperanza): {valor_esperado:.2f}")
# Out:
# x = 5, p = 0.05, x*p = 0.25
#
# Valor esperado (Esperanza): 2.10

# %%
# Varianza y Desviacion Estandar
import math
x = [0, 1, 2, 3, 4, 5]
p = [0.10, 0.25, 0.30, 0.20, 0.10, 0.05]
esperanza = 0
for i in range(len(x)):
  esperanza += x[i] * p[i]
esperanza_cuadrado = 0
for i in range(len(x)):
  esperanza_cuadrado += (x[i]**2)*p[i]
varianza = esperanza_cuadrado - esperanza ** 2
desviacion = math.sqrt(varianza)
print(f"E(X)={esperanza:.2f}")
print(f"E(X^2)={esperanza_cuadrado:.2f}")
print(f"Varianza = {varianza:.2f}")
print(f"Desviacion Estandar = {desviacion:.2f}")
# Out:
# E(X)=2.10
# E(X^2)=6.10
# Varianza = 1.69
# Desviacion Estandar = 1.30

# %%
# Funcion de Distribucion Acumulada
import math
import numpy as np
import matplotlib.pyplot as plt
x = [0, 1, 2, 3, 4, 5]
p = [0.10, 0.25, 0.30, 0.20, 0.10, 0.05]
F=np.cumsum(p)
for xi, fi in zip(x, F):
    print(f"F={xi} = {fi:.2f}")
plt.step(x, F, where='post')
plt.title("Funcion de Distribucion Acumulada (FDA)")
plt.xlabel("Numero de Celulas Anormales")
plt.ylabel("Probabilidad Acumulada")
plt.grid(True)
plt.ylim(0, 1.05)
plt.show()
# Out:
# F=0 = 0.10
# F=1 = 0.35
# F=2 = 0.65
# F=3 = 0.85
# F=4 = 0.95
# F=5 = 1.00

# %% [markdown]
# **¿Cuál es el promedio esperado de células anormales por muestra?**
# 2.10 células anormales
#
# **¿Existe mucha variabilidad entre las muestras?**
# Tiene una variabilidad estandar de 1.30
#
# **¿Qué indica la función acumulada sobre la probabilidad de encontrar un número bajo o alto de células anormales?**
# Encontrar un numero bajo de celulas anormales es de 0.10 mientras que encontrar un numero alto es de 1.00, hay mas probabilidad de encontrar muchos a encontrar pocos
