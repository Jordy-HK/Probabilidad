# %% [markdown]
# <a href="https://colab.research.google.com/github/Jordy-HK/Probabilidad/blob/main/Unidad1/Practica3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Probabilidad y estadistica
# ## Unidad 1
# ### **Practica 3: Tablas de Frecuencia.**
# ### Facilitador: Jose Gabriel Rodriguez Rivas
# ### Alumno: Jordy German Montor de Santiago

# %%
import random
edades=[]
for i in range(100):
  numero_aleatorio=random.randint(18,70)
  edades.append(numero_aleatorio)
print(edades)
print("================================")
import pandas as pd
df = pd.DataFrame(edades, columns=['Edad'])
df.head()
print("================================")
tabla_frecuencias=df['Edad'].value_counts().reset_index()
tabla_frecuencias.columns=['Edad', 'Frecuencia']
tabla_frecuencias=tabla_frecuencias.sort_values(by='Edad')
print('Tabla de distribucion de frecuencias:')
tabla_frecuencias

tabla_frecuencias['Frec. Relativa']=tabla_frecuencias['Frecuencia']/100
tabla_frecuencias

tabla_frecuencias['Frec. Porcentual']=tabla_frecuencias['Frecuencia']/100*100
tabla_frecuencias

tabla_frecuencias['Frec. Acumulada']=tabla_frecuencias['Frecuencia'].cumsum()
tabla_frecuencias
# Out:
# [25, 23, 50, 58, 37, 23, 54, 60, 20, 62, 60, 54, 35, 53, 60, 46, 60, 36, 70, 34, 68, 24, 36, 43, 38, 45, 53, 36, 18, 34, 52, 53, 46, 30, 28, 28, 20, 24, 34, 23, 68, 52, 42, 28, 21, 26, 58, 59, 62, 33, 22, 64, 27, 30, 42, 50, 48, 60, 28, 29, 29, 45, 32, 68, 45, 19, 49, 29, 32, 30, 66, 21, 59, 59, 62, 40, 21, 38, 58, 47, 46, 33, 20, 20, 50, 23, 59, 31, 34, 36, 24, 22, 57, 26, 25, 23, 68, 48, 36, 59]
# ================================
# ================================
# Tabla de distribucion de frecuencias:
#     Edad  Frecuencia  Frec. Relativa  Frec. Porcentual  Frec. Acumulada
# 30    18           1            0.01               1.0                1
# 35    19           1            0.01               1.0                2
# 4     20           4            0.04               4.0                6
# 11    21           3            0.03               3.0                9
# 18    22           2            0.02               2.0               11
# 0     23           5            0.05               5.0               16
# 15    24           3            0.03               3.0               19
# 21    25           2            0.02               2.0               21
# 27    26           2            0.02               2.0               23
# 33    27           1            0.01               1.0               24
# 7     28           4            0.04               4.0               28
# 12    29           3            0.03               3.0               31
# 10    30           3            0.03               3.0               34
# 40    31           1            0.01               1.0               35
# 26    32           2            0.02               2.0               37
# 23    33           2            0.02               2.0               39
# 6     34           4            0.04               4.0               43
# 28    35           1            0.01               1.0               44
# 3     36           5            0.05               5.0               49
# 29    37           1            0.01               1.0               50
# 24    38           2            0.02               2.0               52
# 38    40           1            0.01               1.0               53
# 22    42           2            0.02               2.0               55
# 31    43           1            0.01               1.0               56
# 16    45           3            0.03               3.0               59
# 17    46           3            0.03               3.0               62
# 39    47           1            0.01               1.0               63
# 19    48           2            0.02               2.0               65
# 36    49           1            0.01               1.0               66
# 8     50           3            0.03               3.0               69
# 25    52           2            0.02               2.0               71
# 13    53           3            0.03               3.0               74
# 20    54           2            0.02               2.0               76
# 41    57           1            0.01               1.0               77
# 14    58           3            0.03               3.0               80
# 2     59           5            0.05               5.0               85
# 1     60           5            0.05               5.0               90
# 9     62           3            0.03               3.0               93
# 34    64           1            0.01               1.0               94
# 37    66           1            0.01               1.0               95
# 5     68           4            0.04               4.0               99
# 32    70           1            0.01               1.0              100
