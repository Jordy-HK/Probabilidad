# %% [markdown]
# <a href="https://colab.research.google.com/github/Jordy-HK/Probabilidad/blob/main/Unidad5/PRegCor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Probabilidad y estadistica
# ## Unidad 5
# ### Facilitador: Jose Gabriel Rodriguez Rivas
# ### Alumno: Jordy German Montor de Santiago
# ### **PRACTICA de Regresion Lineal y Correlacion**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from scipy.stats import pearsonr

# %%
from google.colab import files
uploaded = files.upload()

df1 = pd.read_csv('grupo1.csv')
df2 = pd.read_csv('grupo2.csv')
df3 = pd.read_csv('grupo3.csv')
# Out:
#      <input type="file" id="files-67a967c9-9b6f-45a2-a866-f6a424a1af77" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-67a967c9-9b6f-45a2-a866-f6a424a1af77">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
print('Grupo 1')
print(df1.head())
print(df1.describe())
plt.figure(figsize=(6,4))
plt.hist(df1['Calificacion'], bins=10)
plt.title('Calificaciones del Grupo 1')
plt.xlabel('Calificación')
plt.ylabel('Frecuencia')
plt.grid(True)
plt.show()
# Out:
# Grupo 1
#    HorasEstudio  Calificacion
# 0         20.00         75.94
# 1         15.60         87.48
# 2         17.91         79.40
# 3         20.00         73.37
# 4         20.00         83.75
#        HorasEstudio  Calificacion
# count     50.000000      50.00000
# mean      14.352000      83.78820
# std        4.219174       7.83389
# min        3.790000      68.46000
# 25%       12.032500      78.03500
# 50%       14.600000      84.49000
# 75%       17.715000      88.09000
# max       20.000000     100.00000

# %%
print('Grupo 2')
print(df2.head())
print(df2.describe())
plt.figure(figsize=(6,4))
plt.hist(df2['Calificacion'], bins=10)
plt.title('Histograma de Calificaciones del Grupo 2')
plt.xlabel('Calificación')
plt.ylabel('Frecuencia')
plt.grid(True)
plt.show()
# Out:
# Grupo 2
#    HorasEstudio  Calificacion
# 0          3.79          40.0
# 1          6.08          26.1
# 2          7.17          29.0
# 3          7.54          31.9
# 4          8.18          34.8
#        HorasEstudio  Calificacion
# count     50.000000     50.000000
# mean      14.352000     75.912000
# std        4.219174     20.668922
# min        3.790000     26.100000
# 25%       12.032500     63.500000
# 50%       14.600000     78.550000
# 75%       17.715000     93.300000
# max       20.000000     99.000000

# %%
print('Grupo 3')
print(df3.head())
print(df3.describe())
plt.figure(figsize=(6,4))
plt.hist(df3['Calificacion'], bins=10)
plt.title('Histograma de Calificaciones del Grupo 3')
plt.xlabel('Calificación')
plt.ylabel('Frecuencia')
plt.grid(True)
plt.show()
# Out:
# Grupo 3
#    HorasEstudio  Calificacion
# 0          3.79          15.0
# 1          6.08          26.1
# 2          7.17          29.0
# 3          7.54          31.9
# 4          8.18          34.8
#        HorasEstudio  Calificacion
# count     50.000000     50.000000
# mean      14.352000     75.968000
# std        4.219174     23.668867
# min        3.790000     15.000000
# 25%       12.032500     61.000000
# 50%       14.600000     84.950000
# 75%       17.715000     94.375000
# max       20.000000     99.000000

# %%
from sklearn.metrics import r2_score

nombre = 'Grupo 1'
df = df1
x = df[['HorasEstudio']]
y = df['Calificacion']
modelo = LinearRegression()
modelo.fit(x, y)
pendiente = modelo.coef_[0]
intercepto = modelo.intercept_
y_pred = modelo.predict(x)
correlacion, p_valor = pearsonr(df['HorasEstudio'], df['Calificacion'])
r2 = r2_score(y, y_pred)

print(f'===== {nombre} =====')
print(f'Pendiente: {pendiente:.4f}')
print(f'Intercepto: {intercepto:.4f}')
print(f'Correlación de Pearson: {correlacion:.4f}')
print(f'Valor p: {p_valor:.10f}')

plt.figure(figsize=(7,5))
plt.scatter(x, y, label='Datos reales')
plt.plot(x, y_pred, linewidth=2, label='Línea de regresión')
plt.title(f'Regresión Lineal {nombre}')
plt.xlabel('Horas de estudio')
plt.ylabel('Calificación')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# ===== Grupo 1 =====
# Pendiente: -0.1061
# Intercepto: 85.3107
# Correlación de Pearson: -0.0571
# Valor p: 0.6935088469

# %%
from sklearn.metrics import r2_score

nombre = 'Grupo 2'
df = df2
x = df[['HorasEstudio']]
y = df['Calificacion']
modelo = LinearRegression()
modelo.fit(x, y)
pendiente = modelo.coef_[0]
intercepto = modelo.intercept_
y_pred = modelo.predict(x)
correlacion, p_valor = pearsonr(df['HorasEstudio'], df['Calificacion'])
r2 = r2_score(y, y_pred)

print(f'===== {nombre} =====')
print(f'Pendiente: {pendiente:.4f}')
print(f'Intercepto: {intercepto:.4f}')
print(f'Correlación de Pearson: {correlacion:.4f}')
print(f'Valor p: {p_valor:.10f}')

plt.figure(figsize=(7,5))
plt.scatter(x, y, label='Datos reales')
plt.plot(x, y_pred, linewidth=2, label='Línea de regresión')
plt.title(f'Regresión Lineal {nombre}')
plt.xlabel('Horas de estudio')
plt.ylabel('Calificación')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# ===== Grupo 2 =====
# Pendiente: 4.2227
# Intercepto: 15.3075
# Correlación de Pearson: 0.8620
# Valor p: 0.0000000000

# %%
from sklearn.metrics import r2_score

nombre = 'Grupo 3'
df = df3
x = df[['HorasEstudio']]
y = df['Calificacion']
modelo = LinearRegression()
modelo.fit(x, y)
pendiente = modelo.coef_[0]
intercepto = modelo.intercept_
y_pred = modelo.predict(x)
correlacion, p_valor = pearsonr(df['HorasEstudio'], df['Calificacion'])
r2 = r2_score(y, y_pred)

print(f'===== {nombre} =====')
print(f'Pendiente: {pendiente:.4f}')
print(f'Intercepto: {intercepto:.4f}')
print(f'Correlación de Pearson: {correlacion:.4f}')
print(f'Valor p: {p_valor:.10f}')

plt.figure(figsize=(7,5))
plt.scatter(x, y, label='Datos reales')
plt.plot(x, y_pred, linewidth=2, label='Línea de regresión')
plt.title(f'Regresión Lineal {nombre}')
plt.xlabel('Horas de estudio')
plt.ylabel('Calificación')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# ===== Grupo 3 =====
# Pendiente: 5.2857
# Intercepto: 0.1081
# Correlación de Pearson: 0.9422
# Valor p: 0.0000000000

# %% [markdown]
# ## ¿Explicar cuál es la interpretación del coeficiente de regresión en términos de la relación entre el tiempo de estudio y las calificaciones finales?
# Si la pendiente es positiva entonces las calificaciones son mejores al estudiar mas.
# Si la pendiente es negativa entonces las calificaciones son peores.
# ## ¿Cómo se interpreta el coeficiente de correlación en términos de la fuerza y dirección de la relación entre las variables?
# Valores cercanos a -1 tienen una relacion negativa fuerte.
# Valores cercanos a 0 no existe una relacion.
# Valores cercanos a 1 tienen una relacion positiva fuerte.
# ## ¿El modelo de regresión lineal es estadísticamente significativo?
# Para el grupo 1 no.
# Para el grupo 2 si.
# Para el grupo 3 si (siendo este el mas fuerte)
# ## ¿Qué tan confiable es el modelo de regresión para predecir las calificaciones finales de los estudiantes basado en el tiempo de estudio?
# Para el grupo 1 hay mucha dispersion por lo que no es muy confiable.
# Para el grupo 2 es bastante confiable.
# Para el grupo 3 es muy confiable.
# ## Conclusiones
# El grupo 1 no presenta relación lineal entre las horas de estudio y las calificaciones.
# El grupo 2 muestra una relación positiva fuerte.
# El grupo 3 presenta la relación más fuerte y consistente.
# La regresión lineal permite predecir el rendimiento académico cuando existe una correlación significativa.
# Los diagramas de dispersión son de mucha ayudan para visualizar claramente la tendencia de los datos.
