# %% [markdown]
# <a href="https://colab.research.google.com/github/Jordy-HK/Probabilidad/blob/main/Unidad1/Pratica2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Probabilidad y estadistica
# ## Unidad 1
# ### **Practica 2: Maximo, Minimo, Rango y unidad de Datos.**
# ### Facilitador: Jose Gabriel Rodriguez Rivas
# ### Alumno: Jordy German Montor de Santiago

# %%
import random
import matplotlib.pyplot as plt
from statistics import *

# %%
from matplotlib import axes
fabrica1 = []
for i in range (100):
  numero_aleatorio = round(random.uniform(50,100), 2)
  fabrica1.append(numero_aleatorio)
print(fabrica1)

print("==========================================")

fabrica2 = []
for i in range (100):
  numero_aleatorio = round(random.uniform(50,100), 2)
  fabrica2.append(numero_aleatorio)
print(fabrica2)
print("===========================================")

maximo1=max(fabrica1)
minimo1=min(fabrica1)
rango1=maximo1-minimo1
media1=mean(fabrica1)
mediana1=median(fabrica1)
moda1=mode(fabrica1)
desviacion_estandar_fabrica1 = stdev(fabrica1)
print("Estadistica descriptiva de la fabrica 1 \n", "media =", media1,
      "\n mediana= ", mediana1, "\n moda= ", moda1, "\n maximo= ", maximo1,
      "\n minimo= ", minimo1, "\n rango= ", rango1)
print("La desviacion estandar es: ", desviacion_estandar_fabrica1)

maximo2=max(fabrica2)
minimo2=min(fabrica2)
rango2=maximo2-minimo2
media2=mean(fabrica2)
mediana2=median(fabrica2)
moda2=mode(fabrica2)
desviacion_estandar_fabrica2 = stdev(fabrica2)
print("Estadistica descriptiva de la fabrica 2 \n", "media =", media2,
      "\n mediana= ", mediana2, "\n moda= ", moda2, "\n maximo= ", maximo2,
      "\n minimo= ", minimo2, "\n rango= ", rango2)
print("La desviacion estandar es:", desviacion_estandar_fabrica2)

plt.figure(figsize = (8,6))
plt.hist(fabrica1, bins=18, alpha=0.2, color='b', edgecolor="black")
plt.axvline(media1, color='b', linestyle='dashed', linewidth=2, label=f'media={media1:.2f}')
plt.axvline(mediana1, color='r', linestyle='dashed', linewidth=2, label=f'mediana={mediana1:.2f}')
plt.axvline(moda1, color='y', linestyle='dashed', linewidth=2, label=f'moda={moda1:.2f}')
plt.axvline(media1-desviacion_estandar_fabrica1, color='black', linestyle='dashed',
            linewidth=2, label=f'Desv. Estandar={desviacion_estandar_fabrica1:.2f}')
plt.axvline(media1+desviacion_estandar_fabrica1, color='black', linestyle='dashed',
            linewidth=2)
plt.xlabel('Valor')
plt.ylabel('Frecuencia')
plt.title('Produccion diaria de la fabria 1')
plt.legend()
plt.show()

plt.figure(figsize = (8,6))
plt.hist(fabrica2, bins=18, alpha=0.2, color='b', edgecolor="black")
plt.axvline(media1, color='b', linestyle='dashed', linewidth=2, label=f'media={media2:.2f}')
plt.axvline(mediana2, color='r', linestyle='dashed', linewidth=2, label=f'mediana={mediana2:.2f}')
plt.axvline(moda2, color='y', linestyle='dashed', linewidth=2, label=f'moda={moda2:.2f}')
plt.axvline(media2-desviacion_estandar_fabrica2, color='black', linestyle='dashed',
            linewidth=2, label=f'Desv. Estandar={desviacion_estandar_fabrica2:.2f}')
plt.axvline(media1+desviacion_estandar_fabrica2, color='black', linestyle='dashed',
            linewidth=2)
plt.xlabel('Valor')
plt.ylabel('Frecuencia')
plt.title('Produccion diaria de la fabria 2')
plt.legend()
plt.show()

import seaborn as sns
sns.histplot(x = fabrica1, kde = True, kde_kws={'bw_adjust':0.5}, bins=18)
# Out:
# [96.35, 86.58, 69.54, 79.36, 73.04, 93.93, 71.59, 77.98, 64.41, 77.15, 64.18, 60.61, 99.35, 82.66, 75.37, 67.72, 99.74, 97.75, 53.04, 61.62, 95.64, 73.78, 78.68, 73.71, 60.12, 79.78, 87.62, 85.06, 62.99, 73.54, 93.09, 79.15, 95.97, 58.21, 80.93, 78.56, 99.64, 71.06, 59.27, 88.49, 81.1, 55.62, 92.87, 62.72, 76.78, 90.61, 70.78, 59.67, 82.97, 85.02, 95.67, 95.75, 62.32, 99.13, 52.25, 93.98, 77.19, 60.23, 94.9, 93.47, 83.47, 81.21, 75.21, 72.33, 63.09, 82.42, 54.28, 90.38, 67.83, 62.91, 97.6, 51.32, 95.35, 72.38, 66.68, 64.49, 67.52, 54.32, 75.76, 53.34, 70.89, 69.16, 78.24, 52.62, 75.95, 72.47, 84.67, 91.92, 69.42, 66.5, 84.18, 62.31, 52.77, 93.52, 71.26, 92.83, 50.24, 90.15, 83.23, 65.13]
# ==========================================
# [85.96, 74.38, 86.58, 92.64, 52.81, 94.25, 97.72, 94.2, 89.31, 62.3, 94.57, 94.02, 70.1, 99.16, 77.52, 74.64, 52.88, 89.07, 76.09, 76.22, 51.36, 91.35, 69.78, 94.42, 69.64, 99.37, 77.75, 85.58, 58.06, 77.12, 51.85, 73.7, 52.77, 96.56, 64.52, 90.41, 71.13, 56.69, 73.68, 84.57, 83.07, 91.09, 82.46, 90.85, 65.36, 73.45, 79.06, 96.17, 94.48, 90.73, 93.15, 52.76, 95.23, 98.7, 65.28, 68.86, 80.78, 79.79, 60.13, 63.22, 70.28, 73.57, 52.63, 53.85, 51.08, 57.72, 75.21, 95.33, 82.01, 64.16, 93.7, 72.36, 86.52, 78.99, 90.93, 54.46, 66.75, 75.51, 84.99, 78.81, 74.4, 84.58, 75.25, 73.44, 66.82, 97.33, 68.95, 92.63, 99.24, 79.3, 93.33, 66.25, 51.98, 64.16, 79.32, 85.5, 54.84, 59.17, 50.67, 80.95]
# ===========================================
# Estadistica descriptiva de la fabrica 1
#  media = 76.1964
#  mediana=  75.855
#  moda=  96.35
#  maximo=  99.74
#  minimo=  50.24
#  rango=  49.49999999999999
# La desviacion estandar es:  13.97624792642897
# Estadistica descriptiva de la fabrica 2
#  media = 76.8632
#  mediana=  77.32
#  moda=  64.16
#  maximo=  99.37
#  minimo=  50.67
#  rango=  48.7
# La desviacion estandar es: 14.553100393754832
# <Axes: ylabel='Count'>
